# %%
import pickle
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, confusion_matrix

print("Memuat data splits...")
with open('../data/processed/data_splits_tfidf.pkl', 'rb') as f:
    data = pickle.load(f)

X_train = data['X_train']
X_test = data['X_test']
y_train = data['y_train']
y_test = data['y_test']


print("Melatih model Support Vector Machine (LinearSVC)...")
model_svm = LinearSVC(class_weight='balanced', random_state=42, max_iter=2000)
model_svm.fit(X_train, y_train)
print("Pelatihan selesai!\n")

y_pred_svm = model_svm.predict(X_test)

print("=== CLASSIFICATION REPORT (SVM) ===")
print(classification_report(y_test, y_pred_svm, target_names=['Critical', 'Non-Critical']))

cm_svm = confusion_matrix(y_test, y_pred_svm)

print("\n=== CONFUSION MATRIX (SVM) ===")
print("                     [PREDIKSI MODEL]")
print("                    Critical    Non-Critical")
print(f"[ASLI] Critical    [{cm_svm[0][0]:<8}  {cm_svm[0][1]:<8}]")
print(f"[ASLI] Non-Crit    [{cm_svm[1][0]:<8}  {cm_svm[1][1]:<8}]")

# 6. SIMPAN MODEL SVM
with open('../data/processed/model_svm_biner.pkl', 'wb') as f:
    pickle.dump(model_svm, f)
    
print("\nModel SVM berhasil disimpan di model_svm_biner.pkl!")
# Out:
# Memuat data splits...
# Melatih model Support Vector Machine (LinearSVC)...
# d:\kuliah sem 4\nlp\nlp_env\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Pelatihan selesai!
#
# === CLASSIFICATION REPORT (SVM) ===
#               precision    recall  f1-score   support
#
#     Critical       0.99      0.90      0.94     13294
# Non-Critical       0.87      0.99      0.93      9477
#
#     accuracy                           0.93     22771
#    macro avg       0.93      0.94      0.93     22771
# weighted avg       0.94      0.93      0.94     22771
#
#
# === CONFUSION MATRIX (SVM) ===
#                      [PREDIKSI MODEL]
#                     Critical    Non-Critical
# [ASLI] Critical    [11918     1376    ]
# [ASLI] Non-Crit    [113       9364    ]
#
# Model SVM berhasil disimpan di model_svm_biner.pkl!
